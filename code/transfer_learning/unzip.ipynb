# %%
import zipfile
import os
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "drive/My Drive/BTP"
# %ls
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/BTP'
# /content/drive/My Drive/BTP
# bubbleRob00.ttt        Image2h5.ipynb              simpleSynchronousTest.py
# bubbleRob01.ttt        labelme_tests.m             simpleTest.py
# bubbleRob02.ttt        pathPlanningTest.py         testSaveImage.py
# bubbleRob03.ttt        perturbation_lights.py      train_set.zip
# bubbleRob_control.py   perturbation_occlusions.py  train_set.zip.001
# CIFAR_test.ipynb       playground.ipynb            train_set.zip.002
# complexCommandTest.py  readMe.txt                  train_set.zip.003
# create_dataset.py      remoteApi.dll               VGG.ipynb
# dummytrain_set.hdf5    requirements.txt            vrepConst.py
# finalScene.ttt         sim_env00.ttt               vrep.py

# %%
with zipfile.ZipFile('train_set.zip', 'r') as zip_read:
  zip_read.extractall('./')
