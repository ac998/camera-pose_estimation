# %%
import keras
from keras.models import Sequential, Model, load_model
from keras.layers.core import Dense, Flatten
from keras.applications.resnet import ResNet50 
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint
import keras.backend as K
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import os
import cv2
import h5py
import matplotlib.pyplot as plt
from google.colab import drive
import pandas as pd
# to continue using tf 1.x
# Restart runtime using 'Runtime' -> 'Restart runtime...'
#%tensorflow_version 1.x 
# v2 - 50 epochs - gross oerfitting
# v3 - 100 epochs - gross overfitting
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd "drive/My Drive/BTP"
# Out:
# /content/drive/My Drive/BTP

# %%
from metrics_v2 import *

# %%
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'resnet50_v3_adam.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

model_path = os.path.join(save_dir, model_name)

# %%
from tensorflow.python.client import device_lib
from keras import backend
assert len(backend.tensorflow_backend._get_available_gpus()) > 0
assert 'GPU' in str(device_lib.list_local_devices())

# %%
K.clear_session()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:107: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:111: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
img_width = 128
img_height = 128
channels = 3

# %%
base_model = ResNet50(include_top=False, weights='imagenet', input_tensor=None, input_shape=(img_width, img_height, channels), pooling='avg')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 8s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %%
for layer in base_model.layers[:-11]:
  layer.trainable = False
layers = [(layer, layer.name, layer.trainable) for layer in base_model.layers]
layer_info = pd.DataFrame(layers, columns=['Layer type', 'Layer name', 'Layer trainable'])
pd.set_option('display.max_rows', layer_info.shape[0]+1)
layer_info
# Out:
#                                             Layer type  ... Layer trainable
# 0    <keras.engine.input_layer.InputLayer object at...  ...           False
# 1    <keras.layers.convolutional.ZeroPadding2D obje...  ...           False
# 2    <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 3    <keras.layers.normalization.BatchNormalization...  ...           False
# 4    <keras.layers.core.Activation object at 0x7f1b...  ...           False
# 5    <keras.layers.convolutional.ZeroPadding2D obje...  ...           False
# 6    <keras.layers.pooling.MaxPooling2D object at 0...  ...           False
# 7    <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 8    <keras.layers.normalization.BatchNormalization...  ...           False
# 9    <keras.layers.core.Activation object at 0x7f1b...  ...           False
# 10   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 11   <keras.layers.normalization.BatchNormalization...  ...           False
# 12   <keras.layers.core.Activation object at 0x7f1b...  ...           False
# 13   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 14   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 15   <keras.layers.normalization.BatchNormalization...  ...           False
# 16   <keras.layers.normalization.BatchNormalization...  ...           False
# 17   <keras.layers.merge.Add object at 0x7f1b402a79b0>  ...           False
# 18   <keras.layers.core.Activation object at 0x7f1b...  ...           False
# 19   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 20   <keras.layers.normalization.BatchNormalization...  ...           False
# 21   <keras.layers.core.Activation object at 0x7f1b...  ...           False
# 22   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 23   <keras.layers.normalization.BatchNormalization...  ...           False
# 24   <keras.layers.core.Activation object at 0x7f1b...  ...           False
# 25   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 26   <keras.layers.normalization.BatchNormalization...  ...           False
# 27   <keras.layers.merge.Add object at 0x7f1b4017a2e8>  ...           False
# 28   <keras.layers.core.Activation object at 0x7f1b...  ...           False
# 29   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 30   <keras.layers.normalization.BatchNormalization...  ...           False
# 31   <keras.layers.core.Activation object at 0x7f1b...  ...           False
# 32   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 33   <keras.layers.normalization.BatchNormalization...  ...           False
# 34   <keras.layers.core.Activation object at 0x7f1b...  ...           False
# 35   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 36   <keras.layers.normalization.BatchNormalization...  ...           False
# 37   <keras.layers.merge.Add object at 0x7f1b400d2e10>  ...           False
# 38   <keras.layers.core.Activation object at 0x7f1b...  ...           False
# 39   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 40   <keras.layers.normalization.BatchNormalization...  ...           False
# 41   <keras.layers.core.Activation object at 0x7f1b...  ...           False
# 42   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 43   <keras.layers.normalization.BatchNormalization...  ...           False
# 44   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 45   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 46   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 47   <keras.layers.normalization.BatchNormalization...  ...           False
# 48   <keras.layers.normalization.BatchNormalization...  ...           False
# 49   <keras.layers.merge.Add object at 0x7f1afa873908>  ...           False
# 50   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 51   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 52   <keras.layers.normalization.BatchNormalization...  ...           False
# 53   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 54   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 55   <keras.layers.normalization.BatchNormalization...  ...           False
# 56   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 57   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 58   <keras.layers.normalization.BatchNormalization...  ...           False
# 59   <keras.layers.merge.Add object at 0x7f1afa750470>  ...           False
# 60   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 61   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 62   <keras.layers.normalization.BatchNormalization...  ...           False
# 63   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 64   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 65   <keras.layers.normalization.BatchNormalization...  ...           False
# 66   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 67   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 68   <keras.layers.normalization.BatchNormalization...  ...           False
# 69   <keras.layers.merge.Add object at 0x7f1afa6a65c0>  ...           False
# 70   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 71   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 72   <keras.layers.normalization.BatchNormalization...  ...           False
# 73   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 74   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 75   <keras.layers.normalization.BatchNormalization...  ...           False
# 76   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 77   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 78   <keras.layers.normalization.BatchNormalization...  ...           False
# 79   <keras.layers.merge.Add object at 0x7f1afa6030f0>  ...           False
# 80   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 81   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 82   <keras.layers.normalization.BatchNormalization...  ...           False
# 83   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 84   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 85   <keras.layers.normalization.BatchNormalization...  ...           False
# 86   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 87   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 88   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 89   <keras.layers.normalization.BatchNormalization...  ...           False
# 90   <keras.layers.normalization.BatchNormalization...  ...           False
# 91   <keras.layers.merge.Add object at 0x7f1afa4a07f0>  ...           False
# 92   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 93   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 94   <keras.layers.normalization.BatchNormalization...  ...           False
# 95   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 96   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 97   <keras.layers.normalization.BatchNormalization...  ...           False
# 98   <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 99   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 100  <keras.layers.normalization.BatchNormalization...  ...           False
# 101  <keras.layers.merge.Add object at 0x7f1afa3fb588>  ...           False
# 102  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 103  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 104  <keras.layers.normalization.BatchNormalization...  ...           False
# 105  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 106  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 107  <keras.layers.normalization.BatchNormalization...  ...           False
# 108  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 109  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 110  <keras.layers.normalization.BatchNormalization...  ...           False
# 111  <keras.layers.merge.Add object at 0x7f1afa2e3f60>  ...           False
# 112  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 113  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 114  <keras.layers.normalization.BatchNormalization...  ...           False
# 115  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 116  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 117  <keras.layers.normalization.BatchNormalization...  ...           False
# 118  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 119  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 120  <keras.layers.normalization.BatchNormalization...  ...           False
# 121  <keras.layers.merge.Add object at 0x7f1afa235048>  ...           False
# 122  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 123  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 124  <keras.layers.normalization.BatchNormalization...  ...           False
# 125  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 126  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 127  <keras.layers.normalization.BatchNormalization...  ...           False
# 128  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 129  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 130  <keras.layers.normalization.BatchNormalization...  ...           False
# 131  <keras.layers.merge.Add object at 0x7f1afa111278>  ...           False
# 132  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 133  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 134  <keras.layers.normalization.BatchNormalization...  ...           False
# 135  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 136  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 137  <keras.layers.normalization.BatchNormalization...  ...           False
# 138  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 139  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 140  <keras.layers.normalization.BatchNormalization...  ...           False
# 141  <keras.layers.merge.Add object at 0x7f1afa0710b8>  ...           False
# 142  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 143  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 144  <keras.layers.normalization.BatchNormalization...  ...           False
# 145  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 146  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 147  <keras.layers.normalization.BatchNormalization...  ...           False
# 148  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 149  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 150  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 151  <keras.layers.normalization.BatchNormalization...  ...           False
# 152  <keras.layers.normalization.BatchNormalization...  ...           False
# 153  <keras.layers.merge.Add object at 0x7f1af9f152e8>  ...           False
# 154  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 155  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 156  <keras.layers.normalization.BatchNormalization...  ...           False
# 157  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 158  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 159  <keras.layers.normalization.BatchNormalization...  ...           False
# 160  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 161  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 162  <keras.layers.normalization.BatchNormalization...  ...           False
# 163  <keras.layers.merge.Add object at 0x7f1af9e71080>  ...           False
# 164  <keras.layers.core.Activation object at 0x7f1a...  ...           False
# 165  <keras.layers.convolutional.Conv2D object at 0...  ...            True
# 166  <keras.layers.normalization.BatchNormalization...  ...            True
# 167  <keras.layers.core.Activation object at 0x7f1a...  ...            True
# 168  <keras.layers.convolutional.Conv2D object at 0...  ...            True
# 169  <keras.layers.normalization.BatchNormalization...  ...            True
# 170  <keras.layers.core.Activation object at 0x7f1a...  ...            True
# 171  <keras.layers.convolutional.Conv2D object at 0...  ...            True
# 172  <keras.layers.normalization.BatchNormalization...  ...            True
# 173  <keras.layers.merge.Add object at 0x7f1af9d488d0>  ...            True
# 174  <keras.layers.core.Activation object at 0x7f1a...  ...            True
# 175  <keras.layers.pooling.GlobalAveragePooling2D o...  ...            True
#
# [176 rows x 3 columns]

# %%
model = Sequential()
model.add(base_model)
#model.add(Flatten())
model.add(Dense(6))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 2048)              23587712
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 12294
# =================================================================
# Total params: 23,600,006
# Trainable params: 4,477,958
# Non-trainable params: 19,122,048
# _________________________________________________________________

# %%
y_file = 'train_GT.csv'
y_train = np.loadtxt(y_file, dtype=np.float32)

x_file = 'train_set.hdf5'
h5_reader = h5py.File(x_file, 'r')
print(h5_reader.keys())
x_train = h5_reader['train_img']
x_train = np.array(x_train)
h5_reader.close()
# Out:
# KeysView(<HDF5 file "train_set.hdf5" (mode r)>)

# %%
print("Shape of training set : ", x_train.shape)
x_train = x_train.astype('float32', copy=False)
x_train /= 255

print('Shape of training labels : ', y_train.shape)
print(type(x_train[26200]))
print(x_train[26200].dtype)
plt.imshow(x_train[26200])
# Out:
# Shape of training set :  (26399, 128, 128, 3)
# Shape of training labels :  (26399, 6)
# <class 'numpy.ndarray'>
# float32

# %%
adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
#sgd = SGD()
model.compile(optimizer=adam, loss=euclidean_loss(beta=beta), metrics=[euclidean_dist, x_error, y_error, z_error])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
img_gen = ImageDataGenerator()
img_gen.fit(x_train)

# %%
epochs = 100
batch_size = 32
steps_per_epoch = x_train.shape[0] // batch_size
print(steps_per_epoch)
# Out:
# 824

# %%
model.fit_generator(img_gen.flow(x_train, y_train, batch_size = batch_size), verbose=1, steps_per_epoch=steps_per_epoch, epochs=epochs)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/100
# 824/824 [==============================] - 101s 123ms/step - loss: 2.3781 - euclidean_dist: 0.4263 - x_error: 0.3871 - y_error: 0.3606 - z_error: 0.3664
# Epoch 2/100
# 824/824 [==============================] - 91s 110ms/step - loss: 1.3176 - euclidean_dist: 0.2543 - x_error: 0.2223 - y_error: 0.2282 - z_error: 0.2123
# Epoch 3/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.9874 - euclidean_dist: 0.1813 - x_error: 0.1570 - y_error: 0.1671 - z_error: 0.1492
# Epoch 4/100
# 824/824 [==============================] - 91s 110ms/step - loss: 0.6713 - euclidean_dist: 0.1211 - x_error: 0.1067 - y_error: 0.1097 - z_error: 0.0982
# Epoch 5/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.5806 - euclidean_dist: 0.0963 - x_error: 0.0826 - y_error: 0.0843 - z_error: 0.0834
# Epoch 6/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.5457 - euclidean_dist: 0.0841 - x_error: 0.0716 - y_error: 0.0744 - z_error: 0.0730
# Epoch 7/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.5317 - euclidean_dist: 0.0808 - x_error: 0.0732 - y_error: 0.0681 - z_error: 0.0684
# Epoch 8/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.5136 - euclidean_dist: 0.0793 - x_error: 0.0659 - y_error: 0.0676 - z_error: 0.0725
# Epoch 9/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.5229 - euclidean_dist: 0.0830 - x_error: 0.0722 - y_error: 0.0737 - z_error: 0.0701
# Epoch 10/100
# 824/824 [==============================] - 91s 110ms/step - loss: 0.5085 - euclidean_dist: 0.0776 - x_error: 0.0656 - y_error: 0.0665 - z_error: 0.0695
# Epoch 11/100
# 824/824 [==============================] - 91s 110ms/step - loss: 0.4975 - euclidean_dist: 0.0750 - x_error: 0.0639 - y_error: 0.0630 - z_error: 0.0679
# Epoch 12/100
# 824/824 [==============================] - 91s 110ms/step - loss: 0.4886 - euclidean_dist: 0.0759 - x_error: 0.0705 - y_error: 0.0626 - z_error: 0.0639
# Epoch 13/100
# 824/824 [==============================] - 91s 110ms/step - loss: 0.4919 - euclidean_dist: 0.0765 - x_error: 0.0642 - y_error: 0.0689 - z_error: 0.0658
# Epoch 14/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.4739 - euclidean_dist: 0.0716 - x_error: 0.0618 - y_error: 0.0601 - z_error: 0.0642
# Epoch 15/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.4632 - euclidean_dist: 0.0699 - x_error: 0.0570 - y_error: 0.0627 - z_error: 0.0619
# Epoch 16/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.4654 - euclidean_dist: 0.0682 - x_error: 0.0615 - y_error: 0.0594 - z_error: 0.0560
# Epoch 17/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.4474 - euclidean_dist: 0.0632 - x_error: 0.0564 - y_error: 0.0529 - z_error: 0.0549
# Epoch 18/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.4434 - euclidean_dist: 0.0627 - x_error: 0.0554 - y_error: 0.0526 - z_error: 0.0551
# Epoch 19/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.4362 - euclidean_dist: 0.0624 - x_error: 0.0537 - y_error: 0.0536 - z_error: 0.0549
# Epoch 20/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.4287 - euclidean_dist: 0.0596 - x_error: 0.0515 - y_error: 0.0531 - z_error: 0.0501
# Epoch 21/100
# 824/824 [==============================] - 91s 110ms/step - loss: 0.4238 - euclidean_dist: 0.0574 - x_error: 0.0500 - y_error: 0.0479 - z_error: 0.0511
# Epoch 22/100
# 824/824 [==============================] - 91s 110ms/step - loss: 0.4198 - euclidean_dist: 0.0564 - x_error: 0.0484 - y_error: 0.0481 - z_error: 0.0501
# Epoch 23/100
# 824/824 [==============================] - 91s 110ms/step - loss: 0.4175 - euclidean_dist: 0.0551 - x_error: 0.0472 - y_error: 0.0463 - z_error: 0.0499
# Epoch 24/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.4078 - euclidean_dist: 0.0531 - x_error: 0.0457 - y_error: 0.0454 - z_error: 0.0470
# Epoch 25/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.4046 - euclidean_dist: 0.0536 - x_error: 0.0475 - y_error: 0.0454 - z_error: 0.0463
# Epoch 26/100
# 824/824 [==============================] - 91s 110ms/step - loss: 0.4034 - euclidean_dist: 0.0526 - x_error: 0.0452 - y_error: 0.0466 - z_error: 0.0447
# Epoch 27/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3965 - euclidean_dist: 0.0499 - x_error: 0.0421 - y_error: 0.0448 - z_error: 0.0427
# Epoch 28/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3824 - euclidean_dist: 0.0490 - x_error: 0.0412 - y_error: 0.0416 - z_error: 0.0445
# Epoch 29/100
# 824/824 [==============================] - 91s 110ms/step - loss: 0.3880 - euclidean_dist: 0.0485 - x_error: 0.0412 - y_error: 0.0412 - z_error: 0.0436
# Epoch 30/100
# 824/824 [==============================] - 91s 110ms/step - loss: 0.3801 - euclidean_dist: 0.0474 - x_error: 0.0413 - y_error: 0.0401 - z_error: 0.0418
# Epoch 31/100
# 824/824 [==============================] - 91s 110ms/step - loss: 0.3779 - euclidean_dist: 0.0455 - x_error: 0.0385 - y_error: 0.0397 - z_error: 0.0402
# Epoch 32/100
# 824/824 [==============================] - 91s 110ms/step - loss: 0.3759 - euclidean_dist: 0.0455 - x_error: 0.0392 - y_error: 0.0387 - z_error: 0.0401
# Epoch 33/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3751 - euclidean_dist: 0.0459 - x_error: 0.0400 - y_error: 0.0397 - z_error: 0.0396
# Epoch 34/100
# 824/824 [==============================] - 91s 110ms/step - loss: 0.3693 - euclidean_dist: 0.0447 - x_error: 0.0384 - y_error: 0.0383 - z_error: 0.0395
# Epoch 35/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3664 - euclidean_dist: 0.0452 - x_error: 0.0392 - y_error: 0.0378 - z_error: 0.0404
# Epoch 36/100
# 824/824 [==============================] - 91s 110ms/step - loss: 0.3647 - euclidean_dist: 0.0424 - x_error: 0.0368 - y_error: 0.0349 - z_error: 0.0383
# Epoch 37/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3636 - euclidean_dist: 0.0408 - x_error: 0.0347 - y_error: 0.0349 - z_error: 0.0366
# Epoch 38/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3562 - euclidean_dist: 0.0412 - x_error: 0.0354 - y_error: 0.0367 - z_error: 0.0349
# Epoch 39/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3586 - euclidean_dist: 0.0415 - x_error: 0.0347 - y_error: 0.0360 - z_error: 0.0371
# Epoch 40/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3471 - euclidean_dist: 0.0402 - x_error: 0.0333 - y_error: 0.0357 - z_error: 0.0356
# Epoch 41/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3476 - euclidean_dist: 0.0389 - x_error: 0.0335 - y_error: 0.0327 - z_error: 0.0351
# Epoch 42/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3416 - euclidean_dist: 0.0383 - x_error: 0.0319 - y_error: 0.0334 - z_error: 0.0341
# Epoch 43/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3497 - euclidean_dist: 0.0385 - x_error: 0.0321 - y_error: 0.0334 - z_error: 0.0347
# Epoch 44/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3445 - euclidean_dist: 0.0389 - x_error: 0.0330 - y_error: 0.0338 - z_error: 0.0342
# Epoch 45/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3377 - euclidean_dist: 0.0382 - x_error: 0.0321 - y_error: 0.0324 - z_error: 0.0346
# Epoch 46/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3333 - euclidean_dist: 0.0372 - x_error: 0.0317 - y_error: 0.0323 - z_error: 0.0326
# Epoch 47/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3373 - euclidean_dist: 0.0355 - x_error: 0.0303 - y_error: 0.0303 - z_error: 0.0318
# Epoch 48/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3280 - euclidean_dist: 0.0355 - x_error: 0.0299 - y_error: 0.0307 - z_error: 0.0316
# Epoch 49/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3303 - euclidean_dist: 0.0350 - x_error: 0.0294 - y_error: 0.0301 - z_error: 0.0314
# Epoch 50/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3311 - euclidean_dist: 0.0354 - x_error: 0.0303 - y_error: 0.0303 - z_error: 0.0314
# Epoch 51/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3286 - euclidean_dist: 0.0343 - x_error: 0.0290 - y_error: 0.0298 - z_error: 0.0302
# Epoch 52/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.3203 - euclidean_dist: 0.0345 - x_error: 0.0295 - y_error: 0.0300 - z_error: 0.0303
# Epoch 53/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3244 - euclidean_dist: 0.0341 - x_error: 0.0289 - y_error: 0.0290 - z_error: 0.0307
# Epoch 54/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3172 - euclidean_dist: 0.0339 - x_error: 0.0285 - y_error: 0.0292 - z_error: 0.0305
# Epoch 55/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3180 - euclidean_dist: 0.0335 - x_error: 0.0283 - y_error: 0.0289 - z_error: 0.0299
# Epoch 56/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3149 - euclidean_dist: 0.0335 - x_error: 0.0293 - y_error: 0.0284 - z_error: 0.0294
# Epoch 57/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3131 - euclidean_dist: 0.0333 - x_error: 0.0286 - y_error: 0.0289 - z_error: 0.0290
# Epoch 58/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3095 - euclidean_dist: 0.0332 - x_error: 0.0285 - y_error: 0.0287 - z_error: 0.0292
# Epoch 59/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3152 - euclidean_dist: 0.0319 - x_error: 0.0274 - y_error: 0.0277 - z_error: 0.0277
# Epoch 60/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3075 - euclidean_dist: 0.0315 - x_error: 0.0273 - y_error: 0.0268 - z_error: 0.0278
# Epoch 61/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3123 - euclidean_dist: 0.0308 - x_error: 0.0268 - y_error: 0.0262 - z_error: 0.0272
# Epoch 62/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3060 - euclidean_dist: 0.0307 - x_error: 0.0265 - y_error: 0.0259 - z_error: 0.0272
# Epoch 63/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3103 - euclidean_dist: 0.0310 - x_error: 0.0265 - y_error: 0.0268 - z_error: 0.0272
# Epoch 64/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3036 - euclidean_dist: 0.0307 - x_error: 0.0263 - y_error: 0.0255 - z_error: 0.0279
# Epoch 65/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.3057 - euclidean_dist: 0.0297 - x_error: 0.0257 - y_error: 0.0251 - z_error: 0.0263
# Epoch 66/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2972 - euclidean_dist: 0.0302 - x_error: 0.0255 - y_error: 0.0256 - z_error: 0.0273
# Epoch 67/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2961 - euclidean_dist: 0.0303 - x_error: 0.0260 - y_error: 0.0258 - z_error: 0.0270
# Epoch 68/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2986 - euclidean_dist: 0.0301 - x_error: 0.0260 - y_error: 0.0262 - z_error: 0.0261
# Epoch 69/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2915 - euclidean_dist: 0.0293 - x_error: 0.0250 - y_error: 0.0250 - z_error: 0.0262
# Epoch 70/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2895 - euclidean_dist: 0.0290 - x_error: 0.0246 - y_error: 0.0249 - z_error: 0.0257
# Epoch 71/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2932 - euclidean_dist: 0.0286 - x_error: 0.0242 - y_error: 0.0246 - z_error: 0.0256
# Epoch 72/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2896 - euclidean_dist: 0.0288 - x_error: 0.0249 - y_error: 0.0245 - z_error: 0.0256
# Epoch 73/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2903 - euclidean_dist: 0.0282 - x_error: 0.0239 - y_error: 0.0238 - z_error: 0.0256
# Epoch 74/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2883 - euclidean_dist: 0.0276 - x_error: 0.0239 - y_error: 0.0231 - z_error: 0.0248
# Epoch 75/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2848 - euclidean_dist: 0.0283 - x_error: 0.0235 - y_error: 0.0244 - z_error: 0.0256
# Epoch 76/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2869 - euclidean_dist: 0.0281 - x_error: 0.0241 - y_error: 0.0242 - z_error: 0.0249
# Epoch 77/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2832 - euclidean_dist: 0.0278 - x_error: 0.0246 - y_error: 0.0232 - z_error: 0.0244
# Epoch 78/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2869 - euclidean_dist: 0.0281 - x_error: 0.0242 - y_error: 0.0238 - z_error: 0.0249
# Epoch 79/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2832 - euclidean_dist: 0.0275 - x_error: 0.0237 - y_error: 0.0235 - z_error: 0.0244
# Epoch 80/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2781 - euclidean_dist: 0.0276 - x_error: 0.0237 - y_error: 0.0233 - z_error: 0.0247
# Epoch 81/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2815 - euclidean_dist: 0.0276 - x_error: 0.0240 - y_error: 0.0234 - z_error: 0.0246
# Epoch 82/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2753 - euclidean_dist: 0.0265 - x_error: 0.0226 - y_error: 0.0226 - z_error: 0.0236
# Epoch 83/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2750 - euclidean_dist: 0.0265 - x_error: 0.0235 - y_error: 0.0220 - z_error: 0.0235
# Epoch 84/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2731 - euclidean_dist: 0.0267 - x_error: 0.0232 - y_error: 0.0224 - z_error: 0.0240
# Epoch 85/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.2746 - euclidean_dist: 0.0266 - x_error: 0.0231 - y_error: 0.0228 - z_error: 0.0234
# Epoch 86/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2725 - euclidean_dist: 0.0260 - x_error: 0.0224 - y_error: 0.0220 - z_error: 0.0232
# Epoch 87/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2633 - euclidean_dist: 0.0260 - x_error: 0.0222 - y_error: 0.0219 - z_error: 0.0235
# Epoch 88/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2725 - euclidean_dist: 0.0262 - x_error: 0.0226 - y_error: 0.0223 - z_error: 0.0231
# Epoch 89/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2655 - euclidean_dist: 0.0257 - x_error: 0.0222 - y_error: 0.0217 - z_error: 0.0227
# Epoch 90/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2694 - euclidean_dist: 0.0256 - x_error: 0.0216 - y_error: 0.0216 - z_error: 0.0233
# Epoch 91/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2667 - euclidean_dist: 0.0258 - x_error: 0.0224 - y_error: 0.0214 - z_error: 0.0230
# Epoch 92/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2614 - euclidean_dist: 0.0255 - x_error: 0.0219 - y_error: 0.0216 - z_error: 0.0227
# Epoch 93/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2635 - euclidean_dist: 0.0259 - x_error: 0.0229 - y_error: 0.0218 - z_error: 0.0227
# Epoch 94/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2636 - euclidean_dist: 0.0246 - x_error: 0.0212 - y_error: 0.0207 - z_error: 0.0221
# Epoch 95/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2587 - euclidean_dist: 0.0245 - x_error: 0.0214 - y_error: 0.0202 - z_error: 0.0220
# Epoch 96/100
# 824/824 [==============================] - 90s 110ms/step - loss: 0.2583 - euclidean_dist: 0.0249 - x_error: 0.0215 - y_error: 0.0208 - z_error: 0.0225
# Epoch 97/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2514 - euclidean_dist: 0.0247 - x_error: 0.0213 - y_error: 0.0207 - z_error: 0.0221
# Epoch 98/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2557 - euclidean_dist: 0.0241 - x_error: 0.0210 - y_error: 0.0200 - z_error: 0.0215
# Epoch 99/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2569 - euclidean_dist: 0.0244 - x_error: 0.0214 - y_error: 0.0207 - z_error: 0.0212
# Epoch 100/100
# 824/824 [==============================] - 90s 109ms/step - loss: 0.2518 - euclidean_dist: 0.0241 - x_error: 0.0213 - y_error: 0.0201 - z_error: 0.0212

# %%
model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# Saved trained model at /content/drive/My Drive/BTP/saved_models/resnet50_v3_adam.h5
