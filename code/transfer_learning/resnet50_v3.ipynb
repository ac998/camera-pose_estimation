# %%
import keras
from keras.models import Sequential, Model, load_model
from keras.layers.core import Dense, Flatten
from keras.applications.resnet import ResNet50 
from keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping
import keras.backend as K
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import os
import cv2
import h5py
import matplotlib.pyplot as plt
from google.colab import drive
import pandas as pd

# %%
from numpy.random import seed
seed(1)
from tensorflow import set_random_seed
set_random_seed(2)

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd "drive/My Drive/BTP"
# Out:
# /content/drive/My Drive/BTP

# %%
from metrics_v2 import *

# %%
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'resnet50_v4_adam.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

model_path = os.path.join(save_dir, model_name)

# %%
from tensorflow.python.client import device_lib
from keras import backend
assert len(backend.tensorflow_backend._get_available_gpus()) > 0
assert 'GPU' in str(device_lib.list_local_devices())

# %%
K.clear_session()

# %%
img_width = 128
img_height = 128
channels = 3

# %%
base_model = ResNet50(include_top=False, weights='imagenet', input_tensor=None, input_shape=(img_width, img_height, channels), pooling='avg')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %%
for layer in base_model.layers[:-21]:
  layer.trainable = False
layers = [(layer, layer.name, layer.trainable) for layer in base_model.layers]
layer_info = pd.DataFrame(layers, columns=['Layer type', 'Layer name', 'Layer trainable'])
pd.set_option('display.max_rows', layer_info.shape[0]+1)
layer_info
# Out:
#                                             Layer type  ... Layer trainable
# 0    <keras.engine.input_layer.InputLayer object at...  ...           False
# 1    <keras.layers.convolutional.ZeroPadding2D obje...  ...           False
# 2    <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 3    <keras.layers.normalization.BatchNormalization...  ...           False
# 4    <keras.layers.core.Activation object at 0x7efd...  ...           False
# 5    <keras.layers.convolutional.ZeroPadding2D obje...  ...           False
# 6    <keras.layers.pooling.MaxPooling2D object at 0...  ...           False
# 7    <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 8    <keras.layers.normalization.BatchNormalization...  ...           False
# 9    <keras.layers.core.Activation object at 0x7efc...  ...           False
# 10   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 11   <keras.layers.normalization.BatchNormalization...  ...           False
# 12   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 13   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 14   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 15   <keras.layers.normalization.BatchNormalization...  ...           False
# 16   <keras.layers.normalization.BatchNormalization...  ...           False
# 17   <keras.layers.merge.Add object at 0x7efcdd338940>  ...           False
# 18   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 19   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 20   <keras.layers.normalization.BatchNormalization...  ...           False
# 21   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 22   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 23   <keras.layers.normalization.BatchNormalization...  ...           False
# 24   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 25   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 26   <keras.layers.normalization.BatchNormalization...  ...           False
# 27   <keras.layers.merge.Add object at 0x7efcdd289278>  ...           False
# 28   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 29   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 30   <keras.layers.normalization.BatchNormalization...  ...           False
# 31   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 32   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 33   <keras.layers.normalization.BatchNormalization...  ...           False
# 34   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 35   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 36   <keras.layers.normalization.BatchNormalization...  ...           False
# 37   <keras.layers.merge.Add object at 0x7efcdd160da0>  ...           False
# 38   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 39   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 40   <keras.layers.normalization.BatchNormalization...  ...           False
# 41   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 42   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 43   <keras.layers.normalization.BatchNormalization...  ...           False
# 44   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 45   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 46   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 47   <keras.layers.normalization.BatchNormalization...  ...           False
# 48   <keras.layers.normalization.BatchNormalization...  ...           False
# 49   <keras.layers.merge.Add object at 0x7efcdd077898>  ...           False
# 50   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 51   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 52   <keras.layers.normalization.BatchNormalization...  ...           False
# 53   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 54   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 55   <keras.layers.normalization.BatchNormalization...  ...           False
# 56   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 57   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 58   <keras.layers.normalization.BatchNormalization...  ...           False
# 59   <keras.layers.merge.Add object at 0x7efcdcfd5400>  ...           False
# 60   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 61   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 62   <keras.layers.normalization.BatchNormalization...  ...           False
# 63   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 64   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 65   <keras.layers.normalization.BatchNormalization...  ...           False
# 66   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 67   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 68   <keras.layers.normalization.BatchNormalization...  ...           False
# 69   <keras.layers.merge.Add object at 0x7efcdceaa550>  ...           False
# 70   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 71   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 72   <keras.layers.normalization.BatchNormalization...  ...           False
# 73   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 74   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 75   <keras.layers.normalization.BatchNormalization...  ...           False
# 76   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 77   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 78   <keras.layers.normalization.BatchNormalization...  ...           False
# 79   <keras.layers.merge.Add object at 0x7efcdce08080>  ...           False
# 80   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 81   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 82   <keras.layers.normalization.BatchNormalization...  ...           False
# 83   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 84   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 85   <keras.layers.normalization.BatchNormalization...  ...           False
# 86   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 87   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 88   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 89   <keras.layers.normalization.BatchNormalization...  ...           False
# 90   <keras.layers.normalization.BatchNormalization...  ...           False
# 91   <keras.layers.merge.Add object at 0x7efcdcca4780>  ...           False
# 92   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 93   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 94   <keras.layers.normalization.BatchNormalization...  ...           False
# 95   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 96   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 97   <keras.layers.normalization.BatchNormalization...  ...           False
# 98   <keras.layers.core.Activation object at 0x7efc...  ...           False
# 99   <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 100  <keras.layers.normalization.BatchNormalization...  ...           False
# 101  <keras.layers.merge.Add object at 0x7efcdcc07e80>  ...           False
# 102  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 103  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 104  <keras.layers.normalization.BatchNormalization...  ...           False
# 105  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 106  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 107  <keras.layers.normalization.BatchNormalization...  ...           False
# 108  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 109  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 110  <keras.layers.normalization.BatchNormalization...  ...           False
# 111  <keras.layers.merge.Add object at 0x7efcdcae5c88>  ...           False
# 112  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 113  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 114  <keras.layers.normalization.BatchNormalization...  ...           False
# 115  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 116  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 117  <keras.layers.normalization.BatchNormalization...  ...           False
# 118  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 119  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 120  <keras.layers.normalization.BatchNormalization...  ...           False
# 121  <keras.layers.merge.Add object at 0x7efcdca394a8>  ...           False
# 122  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 123  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 124  <keras.layers.normalization.BatchNormalization...  ...           False
# 125  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 126  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 127  <keras.layers.normalization.BatchNormalization...  ...           False
# 128  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 129  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 130  <keras.layers.normalization.BatchNormalization...  ...           False
# 131  <keras.layers.merge.Add object at 0x7efcdc994208>  ...           False
# 132  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 133  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 134  <keras.layers.normalization.BatchNormalization...  ...           False
# 135  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 136  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 137  <keras.layers.normalization.BatchNormalization...  ...           False
# 138  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 139  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 140  <keras.layers.normalization.BatchNormalization...  ...           False
# 141  <keras.layers.merge.Add object at 0x7efcdc86cf98>  ...           False
# 142  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 143  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 144  <keras.layers.normalization.BatchNormalization...  ...           False
# 145  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 146  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 147  <keras.layers.normalization.BatchNormalization...  ...           False
# 148  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 149  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 150  <keras.layers.convolutional.Conv2D object at 0...  ...           False
# 151  <keras.layers.normalization.BatchNormalization...  ...           False
# 152  <keras.layers.normalization.BatchNormalization...  ...           False
# 153  <keras.layers.merge.Add object at 0x7efcdc796278>  ...           False
# 154  <keras.layers.core.Activation object at 0x7efc...  ...           False
# 155  <keras.layers.convolutional.Conv2D object at 0...  ...            True
# 156  <keras.layers.normalization.BatchNormalization...  ...            True
# 157  <keras.layers.core.Activation object at 0x7efc...  ...            True
# 158  <keras.layers.convolutional.Conv2D object at 0...  ...            True
# 159  <keras.layers.normalization.BatchNormalization...  ...            True
# 160  <keras.layers.core.Activation object at 0x7efc...  ...            True
# 161  <keras.layers.convolutional.Conv2D object at 0...  ...            True
# 162  <keras.layers.normalization.BatchNormalization...  ...            True
# 163  <keras.layers.merge.Add object at 0x7efcdc6770b8>  ...            True
# 164  <keras.layers.core.Activation object at 0x7efc...  ...            True
# 165  <keras.layers.convolutional.Conv2D object at 0...  ...            True
# 166  <keras.layers.normalization.BatchNormalization...  ...            True
# 167  <keras.layers.core.Activation object at 0x7efc...  ...            True
# 168  <keras.layers.convolutional.Conv2D object at 0...  ...            True
# 169  <keras.layers.normalization.BatchNormalization...  ...            True
# 170  <keras.layers.core.Activation object at 0x7efc...  ...            True
# 171  <keras.layers.convolutional.Conv2D object at 0...  ...            True
# 172  <keras.layers.normalization.BatchNormalization...  ...            True
# 173  <keras.layers.merge.Add object at 0x7efcdc5cb860>  ...            True
# 174  <keras.layers.core.Activation object at 0x7efc...  ...            True
# 175  <keras.layers.pooling.GlobalAveragePooling2D o...  ...            True
#
# [176 rows x 3 columns]

# %%
model = Sequential()
model.add(base_model)
#model.add(Flatten())
model.add(Dense(6))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 2048)              23587712
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 12294
# =================================================================
# Total params: 23,600,006
# Trainable params: 8,943,622
# Non-trainable params: 14,656,384
# _________________________________________________________________

# %%
y_file = 'train_GT.csv'
y_train = np.loadtxt(y_file, dtype=np.float32)

x_file = 'train_set.hdf5'
h5_reader = h5py.File(x_file, 'r')
print(h5_reader.keys())
x_train = h5_reader['train_img']
x_train = np.array(x_train)
h5_reader.close()
# Out:
# KeysView(<HDF5 file "train_set.hdf5" (mode r)>)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(x_train, y_train, test_size=0.1, random_state=12)

# %%
img_gen = ImageDataGenerator()

# %%
epochs = 100
batch_size = 32
epochs_to_wait_for_improve = 3
steps_per_epoch = X_train.shape[0] // batch_size
print(steps_per_epoch)
# Out:
# 742

# %%
adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
#sgd = SGD()
model.compile(optimizer=adam, loss=euclidean_loss(beta=beta), metrics=[euclidean_dist, x_error, y_error, z_error])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
early_stopping_callback = EarlyStopping(monitor='euclidean_dist', patience=epochs_to_wait_for_improve, restore_best_weights=True)
#checkpoint_callback = ModelCheckpoint(model_name+'.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %%
model.fit_generator(img_gen.flow(X_train, Y_train, batch_size=batch_size),
            steps_per_epoch=steps_per_epoch, validation_data=(X_val, Y_val),
            epochs=epochs, callbacks=[early_stopping_callback])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/100
# 742/742 [==============================] - 116s 157ms/step - loss: 2.1518 - euclidean_dist: 0.4518 - x_error: 0.4025 - y_error: 0.3778 - z_error: 0.3765 - val_loss: 1.9725 - val_euclidean_dist: 0.4897 - val_x_error: 0.5393 - val_y_error: 0.3829 - val_z_error: 0.3850
# Epoch 2/100
# 742/742 [==============================] - 105s 142ms/step - loss: 1.2604 - euclidean_dist: 0.1976 - x_error: 0.1599 - y_error: 0.1755 - z_error: 0.1865 - val_loss: 1.8312 - val_euclidean_dist: 0.4058 - val_x_error: 0.3958 - val_y_error: 0.3215 - val_z_error: 0.4509
# Epoch 3/100
# 742/742 [==============================] - 104s 140ms/step - loss: 1.0541 - euclidean_dist: 0.1985 - x_error: 0.2041 - y_error: 0.1322 - z_error: 0.1835 - val_loss: 0.8769 - val_euclidean_dist: 0.2106 - val_x_error: 0.1075 - val_y_error: 0.1310 - val_z_error: 0.2946
# Epoch 4/100
# 742/742 [==============================] - 106s 142ms/step - loss: 0.8881 - euclidean_dist: 0.1414 - x_error: 0.1058 - y_error: 0.1199 - z_error: 0.1405 - val_loss: 0.8699 - val_euclidean_dist: 0.1433 - val_x_error: 0.1473 - val_y_error: 0.0968 - val_z_error: 0.1242
# Epoch 5/100
# 742/742 [==============================] - 104s 140ms/step - loss: 0.6735 - euclidean_dist: 0.0946 - x_error: 0.0751 - y_error: 0.0955 - z_error: 0.0706 - val_loss: 1.0475 - val_euclidean_dist: 0.1692 - val_x_error: 0.2467 - val_y_error: 0.0994 - val_z_error: 0.0723
# Epoch 6/100
# 742/742 [==============================] - 104s 140ms/step - loss: 0.4043 - euclidean_dist: 0.0511 - x_error: 0.0452 - y_error: 0.0422 - z_error: 0.0451 - val_loss: 0.8024 - val_euclidean_dist: 0.1338 - val_x_error: 0.1321 - val_y_error: 0.1536 - val_z_error: 0.0683
# Epoch 7/100
# 742/742 [==============================] - 103s 139ms/step - loss: 0.3724 - euclidean_dist: 0.0396 - x_error: 0.0360 - y_error: 0.0324 - z_error: 0.0344 - val_loss: 0.6794 - val_euclidean_dist: 0.1469 - val_x_error: 0.1829 - val_y_error: 0.0539 - val_z_error: 0.1565
# Epoch 8/100
# 742/742 [==============================] - 103s 139ms/step - loss: 0.3613 - euclidean_dist: 0.0351 - x_error: 0.0308 - y_error: 0.0297 - z_error: 0.0308 - val_loss: 0.6218 - val_euclidean_dist: 0.0860 - val_x_error: 0.0662 - val_y_error: 0.0795 - val_z_error: 0.0864
# Epoch 9/100
# 742/742 [==============================] - 103s 139ms/step - loss: 0.3576 - euclidean_dist: 0.0330 - x_error: 0.0284 - y_error: 0.0272 - z_error: 0.0303 - val_loss: 0.7619 - val_euclidean_dist: 0.0731 - val_x_error: 0.0788 - val_y_error: 0.0692 - val_z_error: 0.0470
# Epoch 10/100
# 742/742 [==============================] - 105s 142ms/step - loss: 0.3514 - euclidean_dist: 0.0332 - x_error: 0.0277 - y_error: 0.0287 - z_error: 0.0298 - val_loss: 0.6429 - val_euclidean_dist: 0.1079 - val_x_error: 0.1425 - val_y_error: 0.0902 - val_z_error: 0.0431
# Epoch 11/100
# 742/742 [==============================] - 104s 140ms/step - loss: 0.3538 - euclidean_dist: 0.0334 - x_error: 0.0281 - y_error: 0.0271 - z_error: 0.0315 - val_loss: 1.2148 - val_euclidean_dist: 0.1732 - val_x_error: 0.1407 - val_y_error: 0.2377 - val_z_error: 0.0912
# Epoch 12/100
# 742/742 [==============================] - 105s 142ms/step - loss: 0.3481 - euclidean_dist: 0.0355 - x_error: 0.0310 - y_error: 0.0291 - z_error: 0.0322 - val_loss: 0.8364 - val_euclidean_dist: 0.1043 - val_x_error: 0.1519 - val_y_error: 0.0549 - val_z_error: 0.0561

# %%
model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# Saved trained model at /content/drive/My Drive/BTP/saved_models/resnet50_v4_adam.h5
